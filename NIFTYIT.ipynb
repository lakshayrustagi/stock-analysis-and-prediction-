# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('NIFTY_IT_2020.csv')

# %%
df
# Out:
#             Date      Open      High       Low     Close  Shares Traded  \
# 0    01-Jan-2020  15705.90  15746.25  15676.70  15722.15        9390770
# 1    02-Jan-2020  15754.90  15762.10  15679.65  15709.65       15228631
# 2    03-Jan-2020  15727.60  16004.45  15722.65  15936.60       26007478
# 3    06-Jan-2020  15934.60  16067.65  15831.85  15879.80       24001823
# 4    07-Jan-2020  15893.35  15988.70  15799.80  15895.20       24228858
# ..           ...       ...       ...       ...       ...            ...
# 246  23-Dec-2020  23787.80  24228.80  23758.40  24167.75       87281899
# 247  24-Dec-2020  24163.20  24163.20  23828.05  24009.25       31508625
# 248  28-Dec-2020  24065.40  24192.05  24037.80  24100.30       19567634
# 249  29-Dec-2020  24093.05  24424.20  24090.30  24274.05       33910797
# 250  30-Dec-2020  24312.50  24394.75  24176.25  24330.05       29975991
#
#      Turnover (Rs. Cr)
# 0               796.37
# 1              1359.62
# 2              2470.87
# ...

# %%
df.isnull().sum()
# Out:
# Date                 0
# Open                 0
# High                 0
# Low                  0
# Close                0
# Shares Traded        0
# Turnover (Rs. Cr)    0
# dtype: int64

# %%
df.describe()
# Out:
#                Open          High           Low         Close  Shares Traded  \
# count    251.000000    251.000000    251.000000    251.000000   2.510000e+02
# mean   17246.455976  17433.536853  17080.137849  17253.471116   4.207640e+07
# std     3334.302912   3324.504538   3329.669639   3330.758162   2.521164e+07
# min    11159.750000  11602.450000  10991.250000  11179.600000   3.183435e+06
# 25%    14528.425000  14710.250000  14427.450000  14600.450000   2.788417e+07
# 50%    16509.000000  16624.650000  16419.450000  16479.300000   3.632816e+07
# 75%    19953.925000  20211.175000  19780.050000  19908.700000   4.569672e+07
# max    24312.500000  24424.200000  24176.250000  24330.050000   1.957196e+08
#
#        Turnover (Rs. Cr)
# count         251.000000
# mean         3499.788367
# std          2100.254545
# min           380.430000
# 25%          2241.810000
# 50%          2882.290000
# 75%          4118.480000
# max         16871.490000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 251 entries, 0 to 250
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               251 non-null    object
#  1   Open               251 non-null    float64
#  2   High               251 non-null    float64
#  3   Low                251 non-null    float64
#  4   Close              251 non-null    float64
#  5   Shares Traded      251 non-null    int64
#  6   Turnover (Rs. Cr)  251 non-null    float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 13.9+ KB

# %%
import seaborn as sns

# %%
df['Date']=pd.to_datetime(df['Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 251 entries, 0 to 250
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               251 non-null    datetime64[ns]
#  1   Open               251 non-null    float64
#  2   High               251 non-null    float64
#  3   Low                251 non-null    float64
#  4   Close              251 non-null    float64
#  5   Shares Traded      251 non-null    int64
#  6   Turnover (Rs. Cr)  251 non-null    float64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 13.9 KB

# %%
df.head()
# Out:
#         Date      Open      High       Low     Close  Shares Traded  \
# 0 2020-01-01  15705.90  15746.25  15676.70  15722.15        9390770
# 1 2020-01-02  15754.90  15762.10  15679.65  15709.65       15228631
# 2 2020-01-03  15727.60  16004.45  15722.65  15936.60       26007478
# 3 2020-01-06  15934.60  16067.65  15831.85  15879.80       24001823
# 4 2020-01-07  15893.35  15988.70  15799.80  15895.20       24228858
#
#    Turnover (Rs. Cr)
# 0             796.37
# 1            1359.62
# 2            2470.87
# 3            2010.92
# 4            1896.87

# %%
df.iloc[:,1:5].plot(figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
df1=df.set_index(['Date'])

# %%
df1
# Out:
#                 Open      High       Low     Close  Shares Traded  \
# Date
# 2020-01-01  15705.90  15746.25  15676.70  15722.15        9390770
# 2020-01-02  15754.90  15762.10  15679.65  15709.65       15228631
# 2020-01-03  15727.60  16004.45  15722.65  15936.60       26007478
# 2020-01-06  15934.60  16067.65  15831.85  15879.80       24001823
# 2020-01-07  15893.35  15988.70  15799.80  15895.20       24228858
# ...              ...       ...       ...       ...            ...
# 2020-12-23  23787.80  24228.80  23758.40  24167.75       87281899
# 2020-12-24  24163.20  24163.20  23828.05  24009.25       31508625
# 2020-12-28  24065.40  24192.05  24037.80  24100.30       19567634
# 2020-12-29  24093.05  24424.20  24090.30  24274.05       33910797
# 2020-12-30  24312.50  24394.75  24176.25  24330.05       29975991
#
#             Turnover (Rs. Cr)
# Date
# 2020-01-01             796.37
# 2020-01-02            1359.62
# 2020-01-03            2470.87
# 2020-01-06            2010.92
# ...

# %%
df1.iloc[:,1:3].plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df1[df1['High']==df1['High'].min()]
# Out:
#                 Open      High       Low    Close  Shares Traded  \
# Date
# 2020-03-23  11328.25  11602.45  11108.65  11179.6       44666228
#
#             Turnover (Rs. Cr)
# Date
# 2020-03-23            2846.42

# %%
df1[df1['Low']==df1['Low'].min()]
# Out:
#                 Open     High       Low    Close  Shares Traded  \
# Date
# 2020-03-19  11183.95  11698.3  10991.25  11340.0       52457773
#
#             Turnover (Rs. Cr)
# Date
# 2020-03-19            2937.71

# %%
df1[df1['High']==df1['High'].max()]
# Out:
#                 Open     High      Low     Close  Shares Traded  \
# Date
# 2020-12-29  24093.05  24424.2  24090.3  24274.05       33910797
#
#             Turnover (Rs. Cr)
# Date
# 2020-12-29            3559.93

# %%
df1[df1['Low']==df1['Low'].max()]
# Out:
#                Open      High       Low     Close  Shares Traded  \
# Date
# 2020-12-30  24312.5  24394.75  24176.25  24330.05       29975991
#
#             Turnover (Rs. Cr)
# Date
# 2020-12-30            3511.07

# %%
df1.iloc[:,0].plot(figsize=(20,10))
df1.iloc[:,3].plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df_turnover=df.groupby(df['Date'].dt.strftime('%m'))['Turnover (Rs. Cr)'].sum()

# %%
df_turnover
# Out:
# Date
# 01     48465.64
# 02     36987.87
# 03     61758.46
# 04     47816.21
# 05     46061.84
# 06     57528.63
# 07    104194.61
# 08     59021.00
# 09    108277.79
# 10    142809.13
# 11     81244.51
# 12     84281.19
# Name: Turnover (Rs. Cr), dtype: float64

# %%
df_turnover.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df_turnover[df_turnover==df_turnover.max()]
#By analysing monthly we conclude that October has highest turnover
# Out:
# Date
# 10    142809.13
# Name: Turnover (Rs. Cr), dtype: float64

# %%
df_SharesTraded=df.groupby(df['Date'].dt.strftime('%m'))['Shares Traded'].sum()

# %%
df_SharesTraded.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df_SharesTraded.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
corrMatrix=df.corr()

# %%
corrMatrix
# Out:
#                        Open      High       Low     Close  Shares Traded  \
# Open               1.000000  0.998333  0.998741  0.997328       0.153658
# High               0.998333  1.000000  0.997622  0.998857       0.181679
# Low                0.998741  0.997622  1.000000  0.998425       0.147963
# Close              0.997328  0.998857  0.998425  1.000000       0.166467
# Shares Traded      0.153658  0.181679  0.147963  0.166467       1.000000
# Turnover (Rs. Cr)  0.444897  0.470157  0.437547  0.453799       0.916994
#
#                    Turnover (Rs. Cr)
# Open                        0.444897
# High                        0.470157
# Low                         0.437547
# Close                       0.453799
# Shares Traded               0.916994
# Turnover (Rs. Cr)           1.000000

# %%
sns.heatmap(corrMatrix,annot=True)
plt.show()

# %%
# Moving average of the stocks

# %%
ma_day = [10, 30, 60]

for ma in ma_day:
    column_name = f"MA for {ma} days"
    df[column_name] = df['Close'].rolling(ma).mean()

# %%
df[['Close', 'MA for 10 days', 'MA for 30 days', 'MA for 60 days']].plot(figsize=(20,10)).set_title('NIFTYIT')
# Out:
# Text(0.5, 1.0, 'NIFTYIT')

# %%
df2015= pd.read_csv('NIFTY_IT_2015.csv')
df2016= pd.read_csv('NIFTY_IT_2016.csv')
df2017= pd.read_csv('NIFTY_IT_2017.csv')
df2018= pd.read_csv('NIFTY_IT_2018.csv')
df2019= pd.read_csv('NIFTY_IT_2019.csv')
df2020= pd.read_csv('NIFTY_IT_2020.csv')
dfs=[df2015,df2016,df2017,df2018,df2019,df2020]
dfNIFTYIT=pd.concat(dfs,ignore_index=True)

# %%
dfNIFTYIT
# Out:
#              Date      Open      High       Low     Close Shares Traded  \
# 0     01-Jan-2015  11214.80  11235.75  11166.35  11215.70       4246150
# 1     02-Jan-2015  11214.65  11399.10  11214.65  11372.10      10004862
# 2     05-Jan-2015  11369.35  11433.75  11186.95  11248.55       8858018
# 3     06-Jan-2015  11186.10  11186.10  10909.00  10959.90      12515739
# 4     07-Jan-2015  11013.20  11042.35  10889.55  10916.00      10976356
# ...           ...       ...       ...       ...       ...           ...
# 1480  23-Dec-2020  23787.80  24228.80  23758.40  24167.75      87281899
# 1481  24-Dec-2020  24163.20  24163.20  23828.05  24009.25      31508625
# 1482  28-Dec-2020  24065.40  24192.05  24037.80  24100.30      19567634
# 1483  29-Dec-2020  24093.05  24424.20  24090.30  24274.05      33910797
# 1484  30-Dec-2020  24312.50  24394.75  24176.25  24330.05      29975991
#
#      Turnover (Rs. Cr)
# 0               357.51
# 1               964.56
# 2               1059.0
# ...

# %%
#importing required libraries
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM

# %%
#creating dataframe
# data = dfNIFTY50.sort_index(ascending=True, axis=0)
# new_data = pd.DataFrame(index=range(0,len(df)),columns=['Date', 'Close'])
# for i in range(0,len(data)):
#     new_data['Date'][i] = data['Date'][i]
#     new_data['Close'][i] = data['Close'][i]
newdata=dfNIFTYIT[['Date','Close']]
newdata['Date'] = pd.to_datetime(newdata['Date'])
newdata
# Out:
# C:\Users\Lakshay\AppData\Local\Temp/ipykernel_19952/2362354467.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdata['Date'] = pd.to_datetime(newdata['Date'])
#            Date     Close
# 0    2015-01-01  11215.70
# 1    2015-01-02  11372.10
# 2    2015-01-05  11248.55
# 3    2015-01-06  10959.90
# 4    2015-01-07  10916.00
# ...         ...       ...
# 1480 2020-12-23  24167.75
# 1481 2020-12-24  24009.25
# 1482 2020-12-28  24100.30
# 1483 2020-12-29  24274.05
# 1484 2020-12-30  24330.05
#
# [1485 rows x 2 columns]

# %%
new_data=newdata.set_index(['Date'])

# %%
new_data
# Out:
#                Close
# Date
# 2015-01-01  11215.70
# 2015-01-02  11372.10
# 2015-01-05  11248.55
# 2015-01-06  10959.90
# 2015-01-07  10916.00
# ...              ...
# 2020-12-23  24167.75
# 2020-12-24  24009.25
# 2020-12-28  24100.30
# 2020-12-29  24274.05
# 2020-12-30  24330.05
#
# [1485 rows x 1 columns]

# %%
#creating train and test sets
dataset = new_data.values

train = dataset[0:1224,:]
valid = dataset[1224:,:]

# %%
#converting dataset into x_train and y_train
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(dataset)

x_train, y_train = [], []
for i in range(60,len(train)):
    x_train.append(scaled_data[i-60:i,0])
    y_train.append(scaled_data[i,0])
x_train, y_train = np.array(x_train), np.array(y_train)

x_train = np.reshape(x_train, (x_train.shape[0],x_train.shape[1],1))
x_train
# Out:
# array([[[0.11957343],
#         [0.13007328],
#         [0.1217788 ],
#         ...,
#         [0.18737265],
#         [0.16565461],
#         [0.17011235]],
#
#        [[0.13007328],
#         [0.1217788 ],
#         [0.1024004 ],
#         ...,
#         [0.16565461],
#         [0.17011235],
#         [0.17899761]],
#
#        [[0.1217788 ],
#         [0.1024004 ],
#         [0.09945319],
#         ...,
#         [0.17011235],
#         [0.17899761],
#         [0.17779926]],
#
#        ...,
#
#        [[0.42216247],
#         [0.42352195],
#         [0.41563363],
#         ...,
#         [0.38418108],
#         [0.37003917],
#         [0.38237851]],
#
#        [[0.42352195],
#         [0.41563363],
#         [0.4207795 ],
#         ...,
#         [0.37003917],
#         [0.38237851],
#         [0.37179474]],
#
#        [[0.41563363],
#         [0.4207795 ],
#         [0.40870534],
#         ...,
#         [0.38237851],
#         [0.37179474],
#         [0.38709472]]])

# %%
# create and fit the LSTM network
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(x_train.shape[1],1)))
model.add(LSTM(units=50))
model.add(Dense(1))

model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(x_train, y_train, epochs=1, batch_size=1,verbose=2)
# Out:
# 1164/1164 - 25s - loss: 9.7356e-04

# %%
#predicting remaining values, using past 60 from the train data
inputs = new_data[len(new_data) - len(valid) - 60:].values
inputs = inputs.reshape(-1,1)
inputs  = scaler.transform(inputs)

X_test = []
for i in range(60,inputs.shape[0]):
    X_test.append(inputs[i-60:i,0])
X_test = np.array(X_test)

X_test = np.reshape(X_test, (X_test.shape[0],X_test.shape[1],1))
closing_price = model.predict(X_test)
closing_price = scaler.inverse_transform(closing_price)

# %%
#rms=np.sqrt(np.mean(np.power((valid-closing_price),2)

# %%
#for plotting
train = new_data[:1224]
valid = new_data[1224:]
valid['Predictions'] = closing_price
plt_1 = plt.figure(figsize=(20, 10))
plt.plot(train['Close'])
plt.plot()
# Out:
# C:\Users\Lakshay\AppData\Local\Temp/ipykernel_19952/4138422528.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid['Predictions'] = closing_price
# []

# %%
valid[['Close','Predictions']]
