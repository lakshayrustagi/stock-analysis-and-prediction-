# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df= pd.read_csv('nifty50_2020.csv')

# %%
df
# Out:
#             Date      Open      High       Low     Close  Shares Traded  \
# 0    01-Jan-2020  12202.15  12222.20  12165.30  12182.50      304078039
# 1    02-Jan-2020  12198.55  12289.90  12195.25  12282.20      407697594
# 2    03-Jan-2020  12261.10  12265.60  12191.35  12226.65      428770054
# 3    06-Jan-2020  12170.60  12179.10  11974.20  11993.05      396501419
# 4    07-Jan-2020  12079.10  12152.15  12005.35  12052.95      447818617
# ..           ...       ...       ...       ...       ...            ...
# 246  23-Dec-2020  13473.50  13619.45  13432.20  13601.10      458651819
# 247  24-Dec-2020  13672.15  13771.75  13626.90  13749.25      471367730
# 248  28-Dec-2020  13815.15  13885.30  13811.55  13873.20      403634030
# 249  29-Dec-2020  13910.35  13967.60  13859.90  13932.60      439593961
# 250  30-Dec-2020  13980.90  13997.00  13864.95  13981.95      380681073
#
#      Turnover (Rs. Cr)
# 0             10445.68
# 1             15256.55
# 2             16827.27
# 3             16869.22
# 4             17797.68
# ..                 ...
# 246           27073.45
# 247           24764.35
# 248           20923.06
# 249           25154.23
# 250           24633.12
#
# [251 rows x 7 columns]

# %%
df.isnull().sum()
# Out:
# Date                 0
# Open                 0
# High                 0
# Low                  0
# Close                0
# Shares Traded        0
# Turnover (Rs. Cr)    0
# dtype: int64

# %%
df.describe()
# Out:
#                Open          High           Low         Close  Shares Traded  \
# count    251.000000    251.000000    251.000000    251.000000   2.510000e+02
# mean   11164.474502  11243.541434  11054.680876  11150.238645   6.617929e+08
# std     1400.878285   1361.138014   1430.740072   1402.612608   2.007228e+08
# min     7735.150000   8036.950000   7511.100000   7610.250000   1.078681e+08
# 25%    10113.650000  10225.100000  10038.800000  10129.150000   5.440333e+08
# 50%    11363.300000  11418.500000  11289.800000  11322.500000   6.323831e+08
# 75%    12116.950000  12153.425000  12032.300000  12085.000000   7.236908e+08
# max    13980.900000  13997.000000  13864.950000  13981.950000   1.811564e+09
#
#        Turnover (Rs. Cr)
# count         251.000000
# mean        30848.561116
# std          8488.073452
# min          5189.380000
# 25%         26722.800000
# 50%         30813.850000
# 75%         35957.810000
# max         78522.930000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 251 entries, 0 to 250
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               251 non-null    object
#  1   Open               251 non-null    float64
#  2   High               251 non-null    float64
#  3   Low                251 non-null    float64
#  4   Close              251 non-null    float64
#  5   Shares Traded      251 non-null    int64
#  6   Turnover (Rs. Cr)  251 non-null    float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 13.9+ KB

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
df['Date']=pd.to_datetime(df['Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 251 entries, 0 to 250
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               251 non-null    datetime64[ns]
#  1   Open               251 non-null    float64
#  2   High               251 non-null    float64
#  3   Low                251 non-null    float64
#  4   Close              251 non-null    float64
#  5   Shares Traded      251 non-null    int64
#  6   Turnover (Rs. Cr)  251 non-null    float64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 13.9 KB

# %%
df.head()
# Out:
#         Date      Open      High       Low     Close  Shares Traded  \
# 0 2020-01-01  12202.15  12222.20  12165.30  12182.50      304078039
# 1 2020-01-02  12198.55  12289.90  12195.25  12282.20      407697594
# 2 2020-01-03  12261.10  12265.60  12191.35  12226.65      428770054
# 3 2020-01-06  12170.60  12179.10  11974.20  11993.05      396501419
# 4 2020-01-07  12079.10  12152.15  12005.35  12052.95      447818617
#
#    Turnover (Rs. Cr)
# 0           10445.68
# 1           15256.55
# 2           16827.27
# 3           16869.22
# 4           17797.68

# %%
df.iloc[:,1:5].plot(figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
df1=df.set_index(['Date'])

# %%
df1
# Out:
#                 Open      High       Low     Close  Shares Traded  \
# Date
# 2020-01-01  12202.15  12222.20  12165.30  12182.50      304078039
# 2020-01-02  12198.55  12289.90  12195.25  12282.20      407697594
# 2020-01-03  12261.10  12265.60  12191.35  12226.65      428770054
# 2020-01-06  12170.60  12179.10  11974.20  11993.05      396501419
# 2020-01-07  12079.10  12152.15  12005.35  12052.95      447818617
# ...              ...       ...       ...       ...            ...
# 2020-12-23  13473.50  13619.45  13432.20  13601.10      458651819
# 2020-12-24  13672.15  13771.75  13626.90  13749.25      471367730
# 2020-12-28  13815.15  13885.30  13811.55  13873.20      403634030
# 2020-12-29  13910.35  13967.60  13859.90  13932.60      439593961
# 2020-12-30  13980.90  13997.00  13864.95  13981.95      380681073
#
#             Turnover (Rs. Cr)
# Date
# 2020-01-01           10445.68
# 2020-01-02           15256.55
# 2020-01-03           16827.27
# 2020-01-06           16869.22
# 2020-01-07           17797.68
# ...                       ...
# 2020-12-23           27073.45
# 2020-12-24           24764.35
# 2020-12-28           20923.06
# 2020-12-29           25154.23
# 2020-12-30           24633.12
#
# [251 rows x 6 columns]

# %%
df1.iloc[:,1:3].plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df1[df1['High']==df1['High'].min()]
# Out:
#               Open     High     Low    Close  Shares Traded  Turnover (Rs. Cr)
# Date
# 2020-03-24  7848.3  8036.95  7511.1  7801.05      739354439           28282.09

# %%
df1[df1['Low']==df1['Low'].min()]
# Out:
#               Open     High     Low    Close  Shares Traded  Turnover (Rs. Cr)
# Date
# 2020-03-24  7848.3  8036.95  7511.1  7801.05      739354439           28282.09

# %%
df1[df1['High']==df1['High'].max()]
# Out:
#                Open     High       Low     Close  Shares Traded  \
# Date
# 2020-12-30  13980.9  13997.0  13864.95  13981.95      380681073
#
#             Turnover (Rs. Cr)
# Date
# 2020-12-30           24633.12

# %%
df1[df1['Low']==df1['Low'].max()]
# Out:
#                Open     High       Low     Close  Shares Traded  \
# Date
# 2020-12-30  13980.9  13997.0  13864.95  13981.95      380681073
#
#             Turnover (Rs. Cr)
# Date
# 2020-12-30           24633.12

# %%
df1.iloc[:,0].plot(figsize=(20,10))
df1.iloc[:,3].plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df_turnover=df.groupby(df['Date'].dt.strftime('%m'))['Turnover (Rs. Cr)'].sum()

# %%
df_turnover
# Out:
# Date
# 01    430196.47
# 02    400967.73
# 03    643387.33
# 04    568705.25
# 05    645634.79
# 06    771797.76
# 07    809544.22
# 08    666378.46
# 09    699500.15
# 10    664724.54
# 11    792953.71
# 12    649198.43
# Name: Turnover (Rs. Cr), dtype: float64

# %%
df_turnover.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df_turnover[df_turnover==df_turnover.max()]
#By analysing monthly we conclude that July has highest turnover
# Out:
# Date
# 07    809544.22
# Name: Turnover (Rs. Cr), dtype: float64

# %%
df_SharesTraded=df.groupby(df['Date'].dt.strftime('%m'))['Shares Traded'].sum()

# %%
df_SharesTraded.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df_SharesTraded.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
corrMatrix=df.corr()

# %%
corrMatrix
# Out:
#                        Open      High       Low     Close  Shares Traded  \
# Open               1.000000  0.997365  0.997117  0.994288      -0.386983
# High               0.997365  1.000000  0.995326  0.997523      -0.374515
# Low                0.997117  0.995326  1.000000  0.996765      -0.413271
# Close              0.994288  0.997523  0.996765  1.000000      -0.393225
# Shares Traded     -0.386983 -0.374515 -0.413271 -0.393225       1.000000
# Turnover (Rs. Cr) -0.148550 -0.139615 -0.159858 -0.145093       0.544108
#
#                    Turnover (Rs. Cr)
# Open                       -0.148550
# High                       -0.139615
# Low                        -0.159858
# Close                      -0.145093
# Shares Traded               0.544108
# Turnover (Rs. Cr)           1.000000

# %%
sns.heatmap(corrMatrix,annot=True)
plt.show()

# %%
# Moving average of the stocks

# %%
ma_day = [10, 30, 60]

for ma in ma_day:
    column_name = f"MA for {ma} days"
    df[column_name] = df['Close'].rolling(ma).mean()

# %%
df[['Close', 'MA for 10 days', 'MA for 30 days', 'MA for 60 days']].plot(figsize=(20,10)).set_title('NIFTY50')
# Out:
# Text(0.5, 1.0, 'NIFTY50')

# %%
df2015= pd.read_csv('nifty50_2015.csv')
df2016= pd.read_csv('nifty50_2016.csv')
df2017= pd.read_csv('nifty50_2017.csv')
df2018= pd.read_csv('nifty50_2018.csv')
df2019= pd.read_csv('nifty50_2019.csv')
df2020= pd.read_csv('nifty50_2020.csv')
dfs=[df2015,df2016,df2017,df2018,df2019,df2020]
dfNIFTY50=pd.concat(dfs,ignore_index=True)

# %%
dfNIFTY50
# Out:
#              Date      Open      High       Low     Close  Shares Traded  \
# 0     01-Jan-2015   8272.80   8294.70   8248.75   8284.00       56560411
# 1     02-Jan-2015   8288.70   8410.60   8288.70   8395.45      101887024
# 2     05-Jan-2015   8407.95   8445.60   8363.90   8378.40      118160545
# 3     06-Jan-2015   8325.30   8327.85   8111.35   8127.35      172799618
# 4     07-Jan-2015   8118.65   8151.20   8065.45   8102.10      164075424
# ...           ...       ...       ...       ...       ...            ...
# 1477  23-Dec-2020  13473.50  13619.45  13432.20  13601.10      458651819
# 1478  24-Dec-2020  13672.15  13771.75  13626.90  13749.25      471367730
# 1479  28-Dec-2020  13815.15  13885.30  13811.55  13873.20      403634030
# 1480  29-Dec-2020  13910.35  13967.60  13859.90  13932.60      439593961
# 1481  30-Dec-2020  13980.90  13997.00  13864.95  13981.95      380681073
#
#       Turnover (Rs. Cr)
# 0               2321.88
# 1               4715.72
# 2               5525.52
# 3               8089.19
# 4               7464.33
# ...                 ...
# 1477           27073.45
# 1478           24764.35
# 1479           20923.06
# 1480           25154.23
# 1481           24633.12
#
# [1482 rows x 7 columns]

# %%
#importing required libraries
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM

# %%
#creating dataframe
# data = dfNIFTY50.sort_index(ascending=True, axis=0)
# new_data = pd.DataFrame(index=range(0,len(df)),columns=['Date', 'Close'])
# for i in range(0,len(data)):
#     new_data['Date'][i] = data['Date'][i]
#     new_data['Close'][i] = data['Close'][i]
newdata=dfNIFTY50[['Date','Close']]
newdata['Date'] = pd.to_datetime(newdata['Date'])
newdata
# Out:
# C:\Users\Lakshay\AppData\Local\Temp/ipykernel_29744/2821790833.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdata['Date'] = pd.to_datetime(newdata['Date'])
#            Date     Close
# 0    2015-01-01   8284.00
# 1    2015-01-02   8395.45
# 2    2015-01-05   8378.40
# 3    2015-01-06   8127.35
# 4    2015-01-07   8102.10
# ...         ...       ...
# 1477 2020-12-23  13601.10
# 1478 2020-12-24  13749.25
# 1479 2020-12-28  13873.20
# 1480 2020-12-29  13932.60
# 1481 2020-12-30  13981.95
#
# [1482 rows x 2 columns]

# %%
new_data=newdata.set_index(['Date'])

# %%
new_data
# Out:
#                Close
# Date
# 2015-01-01   8284.00
# 2015-01-02   8395.45
# 2015-01-05   8378.40
# 2015-01-06   8127.35
# 2015-01-07   8102.10
# ...              ...
# 2020-12-23  13601.10
# 2020-12-24  13749.25
# 2020-12-28  13873.20
# 2020-12-29  13932.60
# 2020-12-30  13981.95
#
# [1482 rows x 1 columns]

# %%
#creating train and test sets
dataset = new_data.values

train = dataset[0:1224,:]
valid = dataset[1224:,:]

# %%
#converting dataset into x_train and y_train
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(dataset)

x_train, y_train = [], []
for i in range(60,len(train)):
    x_train.append(scaled_data[i-60:i,0])
    y_train.append(scaled_data[i,0])
x_train, y_train = np.array(x_train), np.array(y_train)

x_train = np.reshape(x_train, (x_train.shape[0],x_train.shape[1],1))
x_train
# Out:
# array([[[0.18732484],
#         [0.20322049],
#         [0.20078872],
#         ...,
#         [0.22252491],
#         [0.19561853],
#         [0.19551156]],
#
#        [[0.20322049],
#         [0.20078872],
#         [0.16498249],
#         ...,
#         [0.19561853],
#         [0.19551156],
#         [0.21703381]],
#
#        [[0.20078872],
#         [0.16498249],
#         [0.16138119],
#         ...,
#         [0.19551156],
#         [0.21703381],
#         [0.2168484 ]],
#
#        ...,
#
#        [[0.54868178],
#         [0.55196931],
#         [0.53259358],
#         ...,
#         [0.70450769],
#         [0.71330058],
#         [0.72968829]],
#
#        [[0.55196931],
#         [0.53259358],
#         [0.61380476],
#         ...,
#         [0.71330058],
#         [0.72968829],
#         [0.72501729]],
#
#        [[0.53259358],
#         [0.61380476],
#         [0.6603008 ],
#         ...,
#         [0.72968829],
#         [0.72501729],
#         [0.7408559 ]]])

# %%
rms=np.sqrt(np.mean(np.power((valid-closing_price),2)
rms
# Out:
#   File "C:\Users\Lakshay\AppData\Local\Temp/ipykernel_29744/1174704963.py", line 2
#     rms
#     ^
# SyntaxError: invalid syntax

# %%
#for plotting
train = new_data[:1224]
valid = new_data[1224:]
valid['Predictions'] = closing_price
plt_1 = plt.figure(figsize=(20, 10))
plt.plot(train['Close'])
plt.plot(valid[['Close','Predictions']])
