# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_rows',1000)

# %%
df=pd.read_csv('data2019.csv',sep=';')
df.head(1000)
# Out:
#                                            Scheme Code  \
# 0    Open Ended Schemes ( Equity Scheme - Large Cap...
# 1                                     Tata Mutual Fund
# 2                                               119160
# 3                                               119160
# 4                                               119160
# 5                                               119160
# 6                                               119160
# 7                                               119160
# 8                                               119160
# 9                                               119160
# 10                                              119160
# 11                                              119160
# 12                                              119160
# 13                                              119160
# 14                                              119160
# 15                                              119160
# ...

# %%
df1=pd.read_csv('data2020.csv',sep=';')
df1.head(100)
# Out:
# c:\users\lakshay\appdata\local\programs\python\python38\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                                           Scheme Code  \
# 0   Open Ended Schemes ( Equity Scheme - Large Cap...
# 1                                    Tata Mutual Fund
# 2                                              119160
# 3                                              119160
# 4                                              119160
# 5                                              119160
# 6                                              119160
# 7                                              119160
# 8                                              119160
# 9                                              119160
# 10                                             119160
# 11                                             119160
# ...

# %%
df2=pd.read_csv('data2021.csv',sep=';')
df2.head(100)
# Out:
#                                           Scheme Code  \
# 0   Open Ended Schemes ( Equity Scheme - Large Cap...
# 1                                    Tata Mutual Fund
# 2                                              119160
# 3                                              119160
# 4                                              119160
# 5                                              119160
# 6                                              119160
# 7                                              119160
# 8                                              119160
# 9                                              119160
# 10                                             119160
# 11                                             119160
# 12                                             119160
# 13                                             119160
# 14                                             119160
# 15                                             119160
# ...

# %%
dfs=[df,df1,df2]
for i in dfs:
    i.drop([0,1],inplace=True)

# %%
df.head()
# Out:
#   Scheme Code                                     Scheme Name  \
# 2      119160  Tata Large Cap Fund -Direct Plan Growth Option
# 3      119160  Tata Large Cap Fund -Direct Plan Growth Option
# 4      119160  Tata Large Cap Fund -Direct Plan Growth Option
# 5      119160  Tata Large Cap Fund -Direct Plan Growth Option
# 6      119160  Tata Large Cap Fund -Direct Plan Growth Option
#
#   ISIN Div Payout/ISIN Growth ISIN Div Reinvestment  Net Asset Value  \
# 2                INF277K01QZ7                   NaN         223.3024
# 3                INF277K01QZ7                   NaN         221.1984
# 4                INF277K01QZ7                   NaN         219.2029
# 5                INF277K01QZ7                   NaN         219.9498
# 6                INF277K01QZ7                   NaN         220.9205
#
#    Repurchase Price  Sale Price         Date
# 2               NaN         NaN  01-Jan-2019
# 3               NaN         NaN  02-Jan-2019
# ...

# %%
df.describe()
# Out:
#        Net Asset Value  Repurchase Price  Sale Price
# count     61240.000000               0.0         0.0
# mean        212.545820               NaN         NaN
# std         577.676062               NaN         NaN
# min           0.000000               NaN         NaN
# 25%          10.621900               NaN         NaN
# 50%          15.643300               NaN         NaN
# 75%          57.901900               NaN         NaN
# max        3408.882400               NaN         NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 61302 entries, 2 to 61303
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Scheme Code                  61302 non-null  object
#  1   Scheme Name                  61240 non-null  object
#  2   ISIN Div Payout/ISIN Growth  52640 non-null  object
#  3   ISIN Div Reinvestment        20083 non-null  object
#  4   Net Asset Value              61240 non-null  float64
#  5   Repurchase Price             0 non-null      float64
#  6   Sale Price                   0 non-null      float64
#  7   Date                         61240 non-null  object
# dtypes: float64(3), object(5)
# memory usage: 4.2+ MB

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 69362 entries, 2 to 69363
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Scheme Code                  69362 non-null  object
#  1   Scheme Name                  69300 non-null  object
#  2   ISIN Div Payout/ISIN Growth  59032 non-null  object
#  3   ISIN Div Reinvestment        22138 non-null  object
#  4   Net Asset Value              69300 non-null  float64
#  5   Repurchase Price             0 non-null      float64
#  6   Sale Price                   0 non-null      float64
#  7   Date                         69300 non-null  object
# dtypes: float64(3), object(5)
# memory usage: 4.8+ MB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 44964 entries, 2 to 44965
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Scheme Code                  44964 non-null  object
#  1   Scheme Name                  44898 non-null  object
#  2   ISIN Div Payout/ISIN Growth  37716 non-null  object
#  3   ISIN Div Reinvestment        14924 non-null  object
#  4   Net Asset Value              44898 non-null  float64
#  5   Repurchase Price             0 non-null      float64
#  6   Sale Price                   0 non-null      float64
#  7   Date                         44898 non-null  object
# dtypes: float64(3), object(5)
# memory usage: 3.1+ MB

# %%
df3=pd.concat(dfs,ignore_index=True)

# %%
df3.tail()
# Out:
#        Scheme Code                                    Scheme Name  \
# 175623      144212  Tata Value Fund Series 2 -Regular Plan-Growth
# 175624      144212  Tata Value Fund Series 2 -Regular Plan-Growth
# 175625      144212  Tata Value Fund Series 2 -Regular Plan-Growth
# 175626      144212  Tata Value Fund Series 2 -Regular Plan-Growth
# 175627      144212  Tata Value Fund Series 2 -Regular Plan-Growth
#
#        ISIN Div Payout/ISIN Growth ISIN Div Reinvestment  Net Asset Value  \
# 175623                INF277K013J7                   NaN          12.9860
# 175624                INF277K013J7                   NaN          12.9843
# 175625                INF277K013J7                   NaN          12.9850
# 175626                INF277K013J7                   NaN          12.9856
# 175627                INF277K013J7                   NaN          12.9879
#
#         Repurchase Price  Sale Price         Date
# 175623               NaN         NaN  03-Aug-2021
# ...

# %%
df3.isnull().sum()
# Out:
# Scheme Code                         0
# Scheme Name                       190
# ISIN Div Payout/ISIN Growth     26240
# ISIN Div Reinvestment          118483
# Net Asset Value                   190
# Repurchase Price               175628
# Sale Price                     175628
# Date                              190
# dtype: int64

# %%
df3.shape
# Out:
# (175628, 8)

# %%
# column values Repurchase Price and Sale price have only null value, therefore we can drop these columns

# %%
df4=df3.drop(['Repurchase Price','Sale Price'],axis='columns')

# %%
df4.head()
# Out:
#   Scheme Code                                     Scheme Name  \
# 0      119160  Tata Large Cap Fund -Direct Plan Growth Option
# 1      119160  Tata Large Cap Fund -Direct Plan Growth Option
# 2      119160  Tata Large Cap Fund -Direct Plan Growth Option
# 3      119160  Tata Large Cap Fund -Direct Plan Growth Option
# 4      119160  Tata Large Cap Fund -Direct Plan Growth Option
#
#   ISIN Div Payout/ISIN Growth ISIN Div Reinvestment  Net Asset Value  \
# 0                INF277K01QZ7                   NaN         223.3024
# 1                INF277K01QZ7                   NaN         221.1984
# 2                INF277K01QZ7                   NaN         219.2029
# 3                INF277K01QZ7                   NaN         219.9498
# 4                INF277K01QZ7                   NaN         220.9205
#
#           Date
# 0  01-Jan-2019
# 1  02-Jan-2019
# 2  03-Jan-2019
# 3  04-Jan-2019
# 4  07-Jan-2019

# %%
df4.isnull().sum()
# Out:
# Scheme Code                         0
# Scheme Name                       190
# ISIN Div Payout/ISIN Growth     26240
# ISIN Div Reinvestment          118483
# Net Asset Value                   190
# Date                              190
# dtype: int64

# %%
df4['Scheme Name'].isnull().sum()
# Out:
# 190

# %%
df5=df4.dropna(axis=0,subset=['Scheme Name'])

# %%
df5.head()
# Out:
#   Scheme Code                                     Scheme Name  \
# 0      119160  Tata Large Cap Fund -Direct Plan Growth Option
# 1      119160  Tata Large Cap Fund -Direct Plan Growth Option
# 2      119160  Tata Large Cap Fund -Direct Plan Growth Option
# 3      119160  Tata Large Cap Fund -Direct Plan Growth Option
# 4      119160  Tata Large Cap Fund -Direct Plan Growth Option
#
#   ISIN Div Payout/ISIN Growth ISIN Div Reinvestment  Net Asset Value  \
# 0                INF277K01QZ7                   NaN         223.3024
# 1                INF277K01QZ7                   NaN         221.1984
# 2                INF277K01QZ7                   NaN         219.2029
# 3                INF277K01QZ7                   NaN         219.9498
# 4                INF277K01QZ7                   NaN         220.9205
#
#           Date
# 0  01-Jan-2019
# 1  02-Jan-2019
# 2  03-Jan-2019
# 3  04-Jan-2019
# 4  07-Jan-2019

# %%
df5.isnull().sum()
# Out:
# Scheme Code                         0
# Scheme Name                         0
# ISIN Div Payout/ISIN Growth     26050
# ISIN Div Reinvestment          118293
# Net Asset Value                     0
# Date                                0
# dtype: int64

# %%
df5.shape
# Out:
# (175438, 6)

# %%
#ISIN Div Reinvestment has more the 1,00,000 null value , therefore it is of no use

# %%
df5.drop('ISIN Div Reinvestment',axis='columns',inplace=True)
# Out:
# c:\users\lakshay\appdata\local\programs\python\python38\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df5.isnull().sum()
# Out:
# Scheme Code                        0
# Scheme Name                        0
# ISIN Div Payout/ISIN Growth    26050
# Net Asset Value                    0
# Date                               0
# dtype: int64

# %%
df5.shape
# Out:
# (175438, 5)

# %%
df5.head()
# Out:
#   Scheme Code                                     Scheme Name  \
# 0      119160  Tata Large Cap Fund -Direct Plan Growth Option
# 1      119160  Tata Large Cap Fund -Direct Plan Growth Option
# 2      119160  Tata Large Cap Fund -Direct Plan Growth Option
# 3      119160  Tata Large Cap Fund -Direct Plan Growth Option
# 4      119160  Tata Large Cap Fund -Direct Plan Growth Option
#
#   ISIN Div Payout/ISIN Growth  Net Asset Value         Date
# 0                INF277K01QZ7         223.3024  01-Jan-2019
# 1                INF277K01QZ7         221.1984  02-Jan-2019
# 2                INF277K01QZ7         219.2029  03-Jan-2019
# 3                INF277K01QZ7         219.9498  04-Jan-2019
# 4                INF277K01QZ7         220.9205  07-Jan-2019

# %%
df5.tail()
# Out:
#        Scheme Code                                    Scheme Name  \
# 175623      144212  Tata Value Fund Series 2 -Regular Plan-Growth
# 175624      144212  Tata Value Fund Series 2 -Regular Plan-Growth
# 175625      144212  Tata Value Fund Series 2 -Regular Plan-Growth
# 175626      144212  Tata Value Fund Series 2 -Regular Plan-Growth
# 175627      144212  Tata Value Fund Series 2 -Regular Plan-Growth
#
#        ISIN Div Payout/ISIN Growth  Net Asset Value         Date
# 175623                INF277K013J7          12.9860  03-Aug-2021
# 175624                INF277K013J7          12.9843  04-Aug-2021
# 175625                INF277K013J7          12.9850  05-Aug-2021
# 175626                INF277K013J7          12.9856  06-Aug-2021
# 175627                INF277K013J7          12.9879  09-Aug-2021

# %%
df5['Scheme Name'].unique()
# Out:
# array(['Tata Large Cap Fund -Direct Plan Growth Option',
#        'Tata Large Cap Fund -Regular Plan - Growth Option',
#        'Tata Large Cap Fund- Direct Plan - Payout of IDCW Option',
#        'Tata Large Cap Fund- Regular Plan - Payout of IDCW Option',
#        'Tata Large & MId Cap Fund -Direct Plan- Growth Option',
#        'Tata Large & Mid Cap Fund Direct Plan - Payout of IDCW Option',
#        'Tata Large & Mid Cap Fund Regular Plan - Payout of IDCW Option',
#        'Tata Large & Mid Cap Fund- Regular Plan - Growth Option',
#        'Tata Mid Cap Growth Fund - Direct Plan- Growth Option',
#        'Tata Mid Cap Growth Fund - Direct Plan- IDCW Option',
#        'Tata Mid Cap Growth Fund Regular Plan- Growth Option',
#        'Tata Mid Cap Growth Fund-Regular Plan - IDCW Option',
#        'TATA Small Cap Fund Direct Plan - Reinvestment of Income Distribution cum capital withdrawal option ',
# ...

# %%
SchemeName_count=df4.groupby('Scheme Name').count()

# %%
len(df4['Scheme Name'].unique())
# Out:
# 315

# %%
SchemeName_max=df5.groupby('Scheme Name').max().sort_values('Net Asset Value')

# %%
SchemeName_max.iloc[:,2:]
# Out:
#                                                     Net Asset Value  \
# Scheme Name
# Tata Medium Term Fund- Segregated Portfolio 1 R...           0.6133
# Tata Medium Term Fund- Segregated Portfolio 1 D...           0.6560
# Tata Medium Term Fund -Regular Plan - Growth (S...           1.3446
# Tata Medium Term Fund -Direct Plan -Growth (Seg...           1.4335
# Tata Floating Rate Fund-Regular Plan-IDCW Month...          10.0629
# Tata Floating Rate Fund-Regular Plan-IDCW Month...          10.0629
# Tata Floating Rate Fund-Regular Plan-IDCW Perio...          10.0629
# Tata Floating Rate Fund-Regular Plan-IDCW Perio...          10.0629
# Tata Floating Rate Fund-Regular Plan-IDCW Quart...          10.0629
# Tata Floating Rate Fund-Regular Plan-IDCW Quart...          10.0629
# Tata Floating Rate Fund-Regular Plan-Growth                 10.0629
# Tata Floating Rate Fund-Direct Plan-IDCW Quarte...          10.0705
# Tata Floating Rate Fund-Direct Plan-IDCW Period...          10.0705
# ...

# %%
df_netAssetValue=df5.groupby('Scheme Name').mean().sort_values('Net Asset Value')
df_netAssetValue.iloc[300:,:].plot(kind='bar',figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Scheme Name'>

# %%
df_netAssetValue.iloc[:15,:].plot(kind='bar',figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Scheme Name'>
